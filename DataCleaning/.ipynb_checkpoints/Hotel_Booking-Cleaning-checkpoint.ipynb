# %%
import pandas as pd

data = pd.read_csv(r"E:\1.JOB&Learning_ALL_DOCS\3.DataAnalytics\Projects\Data-Analytics---SQL-Python\DataCleaning\Hotel_Bookings.csv")
data
# df = pd.DataFrame(data)
# df
# Out:
#                  hotel  is_canceled  lead_time  arrival_date_year  \
# 0         Resort Hotel            0        342               2015
# 1         Resort Hotel            0        737               2015
# 2         Resort Hotel            0          7               2015
# 3         Resort Hotel            0         13               2015
# 4         Resort Hotel            0         14               2015
# ...                ...          ...        ...                ...
# 119385      City Hotel            0         23               2017
# 119386      City Hotel            0        102               2017
# 119387      City Hotel            0         34               2017
# 119388  City Hotel**yn            0        109               2017
# 119389      City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# data.info()   #119390
# data.describe()

# print(data.isnull().sum())
# print(data.duplicated().sum())
# Out:
# 31994

# %%
# df[arrival_date] = df.join('arrival_date_month' + '-' + str('arrival_date_year'))
# df['arrival_date'] = pd.to_datetime(df['arrival_date_month'].astype(str) + '-' + 
#                     df['arrival_date_year'].astype(str))
df['arrival_date'] = df['arrival_date_month'].astype(str) + '-' + df['arrival_date_year'].astype(str)
df

# df['arrival_date'] = df['arrival_date_month'].astype(str) + '-' + df['arrival_date_year'].astype(str)
# df
# Out:
#                  hotel  is_canceled  lead_time  arrival_date_year  \
# 0         Resort Hotel            0        342               2015
# 1         Resort Hotel            0        737               2015
# 2         Resort Hotel            0          7               2015
# 3         Resort Hotel            0         13               2015
# 4         Resort Hotel            0         14               2015
# ...                ...          ...        ...                ...
# 119385      City Hotel            0         23               2017
# 119386      City Hotel            0        102               2017
# 119387      City Hotel            0         34               2017
# 119388  City Hotel**yn            0        109               2017
# 119389      City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...
